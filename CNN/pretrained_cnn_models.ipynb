# %% [markdown]
# # Using Pretrained CNN Models
# This notebook demonstrates how to use pretrained Convolutional Neural Network (CNN) models for image classification tasks.

# %% [markdown]
# ## Step 1: Import Required Libraries
# We will use TensorFlow and Keras for loading and using pretrained models.

# %%
# Import Required Libraries
import tensorflow as tf
from tensorflow.keras.applications import VGG16,ResNet50  
#from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# %% [markdown]
# ## Step 2: Load a Pretrained Model
# We will load the VGG16 model, which is pretrained on the ImageNet dataset.

# %%
base_model = ResNet50(include_top=True, input_shape=(224, 224, 3), weights='imagenet')

# %% [markdown]
# # Step 3: Freezing the Layers

# %%
base_model.trainable = False

# %% [markdown]
# ## Step 4: Load Image Image
# We need to preprocess the input image to match the input requirements of the model.

# %%
# Load and Preprocess the Image
image_path = r'c:\Users\Jeevan\Downloads\download.jpg'  # Replace with the path to your image
img = load_img(image_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ## Step 5: Convert to NumPy Array

# %%
x = img_to_array(img)

# %% [markdown]
# ## Step 6: Add a Batch Dimension:

# %%
x = np.expand_dims(x, axis=0)

# %% [markdown]
# ## Step 7: Preprocess the Image

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input
x = preprocess_input(x)

# %% [markdown]
# ## Step 8: Get the Predictions

# %%
preds = base_model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# ## Step 9: Decode Predictions (Get Human-Readable Labels)

# %%
from tensorflow.keras.applications.resnet50 import decode_predictions
decode_predictions(preds, top=3)[0]
# Out:
# [('n03840681', 'ocarina', 0.4425753),
#  ('n03272010', 'electric_guitar', 0.14888911),
#  ('n03935335', 'piggy_bank', 0.07049488)]
